# %% [markdown]
# # Matplotlib 101
#
# For inspiration, see https://matplotlib.org/3.1.1/gallery/index.html

# %%
# Prerequisites and Dependencies

# pyplot (part of matplotlib) provides handy functions to manage plot elements
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d    # mpl_toolkits is a subpackage of matplotlib
# %matplotlib inline

import numpy as np
import pandas as pd

print("Numpy Version: ", np.__version__)
print("Pandas Version: ", pd.__version__)
print("Matplotlib Version: ", mpl.__version__)
# Out:
# Numpy Version:  2.1.3
# Pandas Version:  2.2.3
# Matplotlib Version:  3.9.2

# %% [markdown]
# ## Scatter Plot

# %%
X = [1, 2, 3, 4, 5, 6]
Y = [60, 100, 120, 150, 210, 250]

plt.scatter(X,Y)
plt.show()

# %% [markdown]
# ## Connect Scatter Plot with Lines

# %%
# Connect Scatter Plot with Lines
plt.scatter(X,Y)
plt.plot(X,Y)
plt.show()

# %% [markdown]
# ### Add Axis Titles

# %%
plt.scatter(X,Y)
plt.plot(X,Y)
plt.title("Odometer vs. Time")
plt.xlabel("Time (h)")
plt.ylabel("Odometer (km)")
plt.show()

# %% [markdown]
# ### Use styles
#
# Style reference:
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
plt.scatter(X,Y)
plt.plot(X,Y)
plt.title("Odometer vs. Time")
plt.xlabel("Time (h)")
plt.ylabel("Odometer (km)")
plt.style.use('seaborn-v0_8')
plt.show()

# %% [markdown]
# ## plt.figure() and plt.axes()
#
# plt.Figure() can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels. The axes (an instance of the class plt.Axes) is a bounding box with ticks and labels, which will eventually contain the plot elements that make up the visualization.

# %%
fig = plt.figure()
ax = plt.axes()

# %%
# Add a single plot
x = np.linspace(0, 10, 100)
y = np.sin(x)

fig = plt.figure()
ax = plt.axes()
ax.plot(x, y)
plt.show()

# %%
# Set the Major ticks
ax.set_xticks([0, 2, 4, 6, 8, 10])
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
# Display Minor ticks
ax.minorticks_on()
# Set the minor ticks for x-axis
ax.set_xticks(np.arange(0, 11, 0.5), minor=True)
# Set the minor ticks for y-axis
ax.set_yticks(np.arange(-1, 1.1, 0.25), minor=True)
fig

# %%
# Set the Major ticks with custom labels
ax.set_xticklabels(['zero', 'two', 'four', 'six', 'eight', 'ten'])
ax.set_yticklabels(['minus one', 'minus half', 'zero', 'plus half', 'plus one'])
fig

# %%
# Plotting with a label to reference in the legend, and with markers
ax.plot(x, y, label='Sine curve', marker='o')
# Display the legend on the plot
ax.legend()
fig

# %% [markdown]
# ## Using subplots

# %%
plt.style.use('default')
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots()
#x = np.random.randint(-10,10, size=20)
x = np.arange(-10,10, step=1, dtype=int)
y = x*x + 2*x -5
plt.scatter(x,y)
plt.plot(x,y)
plt.show()
# Out:
# &lt;Figure size 640x480 with 1 Axes&gt;

# %% [markdown]
# ### Plotting multiple lines

# %%
fig, ax = plt.subplots()
x = x = np.arange(0,20, step=1, dtype=int)
y = 2*x
plt.plot(x,y)
plt.plot(x,x+2)
plt.show()

# %% [markdown]
# ### Line styles
#
# https://matplotlib.org/gallery/lines_bars_and_markers/line_styles_reference.html

# %%
fig, ax = plt.subplots()
plt.style.use('seaborn-v0_8-bright')
x = np.arange(0,20, step=0.1, dtype=float)
y = 2*x

# Default
plt.plot(x,y)

# Specify red color and solid line
plt.plot(x, 3*np.cos(x), color=(1.0, 0.0, 0.0), linestyle='-')

# Specify green color and dashed line
plt.plot(x, 3*np.sin(x), color=(0.0, 1.0, 0.0), linestyle='--')

# Speficy blue color and dotted line
plt.plot(x, 3*np.sin(x)+10, color='b', linestyle=':')

# Speficy grayscale color and dashes + dots line
plt.plot(x, 3*np.cos(x)+10, color='0.77', linestyle='-.')

# Speficy hex color (magenta) and dotted line
plt.plot(x, 3*np.cos(x)+20, color='#FF00FF', linestyle=':')

# %% [markdown]
# ### Set limits to Axis

# %%
fig, ax = plt.subplots()
x = np.arange(0,20, step=0.1, dtype=float)
y = 2*x
plt.xlim(-5,15)
plt.ylim(0,20)
plt.plot(x, 3*np.cos(x), color=(1.0, 0.0, 0.0), linestyle='-')
plt.plot(x, 3*np.cos(x)+20, color='#FF00FF', linestyle=':')

# %%
plt.style.use('_mpl-gallery')

# Create some data
x = np.linspace(0, 10, 100)
y = 4 + np.sin(x)
x2 = np.linspace(0, 10, 25)
y2 = 4 + np.sin(2*x2)

# Create plot
fig, ax = plt.subplots()

ax.plot(x2, y2 + 2.5, 'x', markeredgewidth=2)
ax.plot(x, y, linewidth=2.0)
ax.plot(x2, y2 - 2.5, 'o-', linewidth=2.0)

ax.set(xticks=np.arange(1,10), yticks=np.arange(1,10))

plt.show()

# %% [markdown]
# ## Label Plots

# %%
plt.plot(x, np.sin(x), label="sin(x)", color='r')
plt.plot(x, np.cos(x), label="cos(x)", color='g')
plt.legend()   # Show labels
plt.xlabel("x")
plt.ylabel("trig(x)")
# Out:
# Text(0, 0.5, 'trig(x)')

# %% [markdown]
# ## Multiple Subplots

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(12, 4))

# %%
# Plot to different subplots
rng = np.random.default_rng(3)
x = rng.standard_normal(100)
y = rng.standard_normal(100)
ax[0,1].plot(x, y, 'o')
ax[1,2].scatter(x, y, marker='+')
fig

# %% [markdown]
# ## Saving a Figure

# %%
fig.savefig("Figure.png", dpi=400)
fig.savefig("Figure.pdf", dpi=200)

# %% [markdown]
# ## Contours

# %%
fig, ax = plt.subplots(figsize=(6, 6))
x = np.linspace(-np.pi, np.pi, 50)
y = x
f = np.multiply.outer(np.cos(y), 1 / (1 + x**2))
ax.contour(x, y, f)

# %%
# Increase resolution
fig, ax = plt.subplots(figsize=(6, 6))
ax.contour(x, y, f, levels=45)

# %% [markdown]
# ## Heatmap

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(f)

# %% [markdown]
# # Boxplot

# %%
df_cars = pd.read_csv("data/cars.csv")
df_cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Replace the cylinders column with a categorical version of cylinders.
df_cars.cylinders = pd.Series(df_cars.cylinders, dtype='category')
df_cars.cylinders.dtype
# Out:
# CategoricalDtype(categories=[3, 4, 5, 6, 8], ordered=False, categories_dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
df_cars.boxplot('mpg', by='cylinders', ax=ax);

# %% [markdown]
# ## Histogram

# %%
fig, ax = plt.subplots(figsize=(8, 8))
df_cars.hist('mpg', color='green', ax=ax)
# Out:
# array([<Axes: title={'center': 'mpg'}>], dtype=object)

# %% [markdown]
# ## 3D Scatter Plot

# %%
# Make some 3D Points
def create_box_points(x_size=1.0, y_size=1.0, z_size=1.0, step=0.05, x_offset=0.0, y_offset=0.0, z_offset=0.0):
    """ Create an box shape points array for testing
    """
    points_array = []
    x_range = abs(x_size/2)
    y_range = abs(y_size/2)
    z_range = abs(x_size/2)
    
    for z in [-z_range, z_range]:
        for x in np.arange(-x_range, x_range, step):
            for y in np.arange(-y_range, y_range, step):
                point = [x + x_offset, y + y_offset, z + z_offset]
                points_array.append(point)

    for y in [-y_range, y_range]:
        for x in np.arange(-x_range, x_range, step):
            for z in np.arange(-z_range, z_range, step):
                point = [x + x_offset, y + y_offset, z + z_offset]
                points_array.append(point)

    for x in [-x_range, x_range]:
        for y in np.arange(-y_range, y_range, step):
            for z in np.arange(-z_range, z_range, step):
                point = [x + x_offset, y + y_offset, z + z_offset]
                points_array.append(point)

    return np.array(points_array)

points_array = create_box_points(x_size=2.0, y_size=2.0, z_size=2.0, step=0.2)
print(f"Points Array type: {type(points_array)}")
print(f"Points Array shape: {points_array.shape}")
# Out:
# Points Array type: <class 'numpy.ndarray'>
# Points Array shape: (600, 3)

# %%
# Plot in 3D Scatter Plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(points_array[:,0], points_array[:,1], points_array[:,2], marker='.')
plt.show()
# Out:
# &lt;Figure size 640x480 with 1 Axes&gt;

# %% [markdown]
# ### Machine Learning Activation Functions

# %%
# Define the sigmoid function and its derivative
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    s = sigmoid(x)
    return s * (1 - s)

# Create an array of x values
x = np.linspace(-10, 10, 400)

# Calculate sigmoid and its derivative
y_sigmoid = sigmoid(x)
y_derivative = sigmoid_derivative(x)

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(x, y_sigmoid, label='Sigmoid Function')
plt.plot(x, y_derivative, label='Sigmoid Derivative', linestyle='--')
plt.title('Sigmoid Function and Its Derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Define tanh function and its derivative
def tanh(x):
    return np.tanh(x)

def tanh_derivative(x):
    return 1 - np.tanh(x)**2


# Calculate tanh and its derivative
y_tanh = tanh(x)
y_tanh_derivative = tanh_derivative(x)

# Plot tanh and its derivative
plt.figure(figsize=(8, 6))
plt.plot(x, y_tanh, label='Tanh Function')
plt.plot(x, y_tanh_derivative, label='Tanh Derivative', linestyle='--')
plt.title('Tanh Function and Its Derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Define ReLU function and its derivative
def relu(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return np.where(x > 0, 1, 0)


# Calculate ReLU and its derivative
y_relu = relu(x)
y_relu_derivative = relu_derivative(x)

# Plot ReLU and its derivative
plt.figure(figsize=(8, 6))
plt.plot(x, y_relu, label='ReLU Function')
plt.plot(x, y_relu_derivative, label='ReLU Derivative', linestyle='--')
plt.title('ReLU Function and Its Derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# %%
line_width = 2.5

plt.rcParams.update({'font.size': 20})
# Create a figure with 3 subplots in a horizontal row
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# Plot Sigmoid and its derivative
axs[0].plot(x, y_sigmoid, label='Function', linewidth=line_width)
axs[0].plot(x, y_derivative, label='Derivative', linestyle='--', linewidth=line_width)
axs[0].set_title('Sigmoid')
#axs[0].set_xlabel('x')
#axs[0].set_ylabel('y')
axs[0].grid(True)
axs[0].legend()

# Plot Tanh and its derivative
axs[1].plot(x, y_tanh, label='Function', linewidth=line_width)
axs[1].plot(x, y_tanh_derivative, label='Derivative', linestyle='--', linewidth=line_width)
axs[1].set_title('Tanh')
#axs[1].set_xlabel('x')
#axs[1].set_ylabel('y')
axs[1].grid(True)
axs[1].legend()

# Plot ReLU and its derivative
axs[2].plot(x, y_relu, label='Function', linewidth=line_width)
axs[2].plot(x, y_relu_derivative, label='Derivative', linestyle='--', linewidth=line_width)
axs[2].set_title('ReLU')
#axs[2].set_xlabel('x')
#axs[2].set_ylabel('y')
axs[2].grid(True)
axs[2].legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3D Visualization

# %%
ax = plt.axes(projection='3d')

# %% [markdown]
# ### Generate Test Data

# %%
def LoG(x, y, sigma):
    temp = (x ** 2 + y ** 2) / (2 * sigma ** 2)
    return -1 / (np.pi * sigma ** 4) * (1 - temp) * np.exp(-temp)

N = 49
half_N = N // 2
X2, Y2 = np.meshgrid(range(N), range(N))
Z2 = -LoG(X2 - half_N, Y2 - half_N, sigma=8)
X1 = np.reshape(X2, -1)
Y1 = np.reshape(Y2, -1)
Z1 = np.reshape(Z2, -1)

# %% [markdown]
# ### 3D Plots

# %%
# Wireframe Plot
ax = plt.axes(projection='3d')
ax.plot_wireframe(X2, Y2, Z2, color='r')

# %%
# Surface Plot
ax = plt.axes(projection='3d')
ax.plot_surface(X2, Y2, Z2, cmap='jet')

# %%
# Scatter Plot
ax = plt.axes(projection='3d')
ax.scatter(X1, Y1, Z1, c=Z1, cmap='BrBG', linewidth=1)

# %%
# Contour Plot
ax = plt.axes(projection='3d')
ax.contour3D(X2, Y2, Z2, 55, cmap='twilight_shifted')

# %%
# Trisurf Plot
ax = plt.axes(projection='3d')
ax.plot_trisurf(X1, Y1, Z1, cmap='twilight_shifted')
