# %% [markdown]
# # Files 101

# %% [markdown]
# ## Check file or directory existence and type

# %%
#import os.path
from os import path
print("File 'first.txt' exists: " + str(path.exists("first.txt")))
print("File 'third.txt' exists: " + str(path.exists("third.txt")))
# Out:
# File 'first.txt' exists: True
# File 'third.txt' exists: False

# %%
#import os.path
from os import path
print("Is 'first.txt' a file?: " + str(path.isfile("first.txt")))
print("Is 'third.txt' a file?: " + str(path.isfile("third.txt")))
print("Is .. a file?: " + str(path.isfile("..")))
print("Is .. a directory?: " + str(path.isdir("..")))
# Out:
# Is 'first.txt' a file?: True
# Is 'third.txt' a file?: False
# Is .. a file?: False
# Is .. a directory?: True

# %% [markdown]
# ### Find all files in a directory

# %%
import os 
file_names = os.listdir("images")
print(file_names)
for file_name in os.listdir("images"):
    if file_name.endswith(".jpg"):
        print(file_name)
# Out:
# ['image_8x8.jpg', 'miami_beach.jpg', 'motorcycles.jpg', 'new_image_8x8.png']
# image_8x8.jpg
# miami_beach.jpg
# motorcycles.jpg

# %% [markdown]
# ### Using glob

# %%
import glob

# Find all .jpg files in the 'images' subdirectory
jpg_files = glob.glob("images/*.jpg")
print(jpg_files)

# Recursively find all .py files in the current directory and all subdirectories
python_files_recursive = glob.glob("**/*.py", recursive=True)
print(python_files_recursive)
# Out:
# ['images\\image_8x8.jpg', 'images\\miami_beach.jpg', 'images\\motorcycles.jpg']
# ['argparse_101.py', 'thread_101.py', 'PyQt5\\pyqt5_101.py', 'PyQt5\\pyqt5_button_label.py', 'PyQt5\\pyqt5_button_label_with_code.py', 'PyQt5\\pyqt5_loginbox_widget.py', 'PyQt5\\pyqt5_loginbox_widget_main.py', 'PyTest_101\\item_database.py', 'PyTest_101\\shopping_cart.py', 'PyTest_101\\test_shopping_cart.py', 'sockets\\socket_client.py', 'sockets\\socket_client_pickle_deserialized.py', 'sockets\\socket_client_simple.py', 'sockets\\socket_server.py', 'sockets\\socket_server_pickle_serialized.py', 'sockets\\socket_server_simple.py', 'UnitTest_101\\calc.py', 'UnitTest_101\\employee.py', 'UnitTest_101\\test_calc.py', 'UnitTest_101\\test_employee.py']

# %% [markdown]
# ### Extract filename and extension from long path

# %%
import os

full_path = "/home/jari/projects/foo/main.py"
print(f"Full Path: {full_path}")

# Extract the file name (with extension)
file_name = os.path.basename(full_path)
print(f"File Name: {file_name}")

# Extract directory path:
dir_path = os.path.dirname(full_path)
print(f"Directory Path: {dir_path}")

# Separate the name from the extension:
name, extension = os.path.splitext(file_name)
print(f"Name without extension: {name}")
print(f"Extension: {extension}")
# Out:
# Full Path: /home/jari/projects/foo/main.py
# File Name: main.py
# Directory Path: /home/jari/projects/foo
# Name without extension: main
# Extension: .py

# %% [markdown]
# ## Read with open()

# %%
# Open file and create file object
file1 = open("first.txt","r")

# %%
# print the file name
print("File name:", file1.name)
# print the file mode
print("File mode:", file1.mode)
# Out:
# File name: first.txt
# File mode: r

# %%
# Read the contents
file_content = file1.read()
print(file_content)
# Out:
# Test file 1 ... 1234567890
# Second line
# Third line

# %%
# Close the file, IMPORTANT!
print(file1.closed)
file1.close()
print(file1.closed)
# Out:
# False
# True

# %% [markdown]
# ## Recommended way: 'with' block

# %%
# Open amd read file w/ 'with' block
with open("first.txt", "r") as file1:
    file_content = file1.read()
    print(file_content)
# Out:
# Test file 1 ... 1234567890
# Second line
# Third line

# %%
# Verify that file automatically closed
file1.closed
# Out:
# True

# %% [markdown]
# ### Read portion of a file

# %%
# Read 11 first characters
with open("first.txt", "r") as file1:
    text = file1.read(11)
    print(text)
# Out:
# Test file 1

# %%
# Read 5 characters at a time
with open("first.txt", "r") as file1:
    print(file1.read(5))
    print(file1.read(5))
    print(file1.read(5))
    print(file1.read(5))
# Out:
# Test
# file
# 1 ...
#  1234

# %% [markdown]
# ### Read One Line

# %%
# Read one line
with open("first.txt", "r") as file1:
    line1 = file1.readline()
    print(f"First Line: '{line1}'")
# Out:
# First Line: 'Test file 1 ... 1234567890
# '

# %%
# One can pass number of characters argument to readline(), but it will not read past one line
with open("first.txt", "r") as file1:
    text = file1.readline(1000)
    print(text)
# Out:
# Test file 1 ... 1234567890

# %% [markdown]
# ### Iterate over lines

# %%
# Iterate over lines
with open("first.txt", "r") as file1:
    i = 0
    for line in file1: 
        print(f"Line {str(i)}: {line}")
        i = i + 1
# Out:
# Line 0: Test file 1 ... 1234567890
#
# Line 1: Second line
#
# Line 2: Third line

# %% [markdown]
# ### Read all lines to a list

# %%
# Read all lines to a list
with open("first.txt", "r") as file1:
    lines_list = file1.readlines()

print(lines_list)
# Out:
# ['Test file 1 ... 1234567890\n', 'Second line\n', 'Third line\n']

# %% [markdown]
# ## Write to a file

# %%
# Write to a file
with open("junk1.txt", "w") as fileW:
    fileW.write("This is writing some random text to a file")

# Read back to check
with open("junk1.txt", "r") as fileR:
    print(fileR.read())
# Out:
# This is writing some random text to a file

# %%
# Write List of text lines
Lines = ["Text line 1\n", "Text line 2\n", "Text line 3\n", "Text line 4\n"]
with open("junk2.txt", "w") as fileW:
    for line in Lines:
        fileW.write(line)

# Read back to check
with open("junk2.txt", "r") as fileR:
    print(fileR.read())
# Out:
# Text line 1
# Text line 2
# Text line 3
# Text line 4

# %% [markdown]
# ### Appending a File

# %%
# Append to the end of file
with open("junk2.txt", "a") as fileW:
    fileW.write("Text line 5\n")
    fileW.write("Text line 6\n")
    fileW.write("Text line 7\n")

# Read back to check
with open("junk2.txt", "r") as fileR:
    print(fileR.read())
# Out:
# Text line 1
# Text line 2
# Text line 3
# Text line 4
# Text line 5
# Text line 6
# Text line 7

# %% [markdown]
# ### tell() - get current position in a file,  seek() - move to a position

# %%
# "a+" opens for appending and reading
with open("junk2.txt", "a+") as fileW:
    print(f"Position after open for append: {fileW.tell()}")

    text = fileW.read()
    if (not text):
        print("Nothing to read")
    else:
        print(text)

    fileW.seek(0,0)  # 0 bytes from the beginning
    print(f"Position after seek: {fileW.tell()}")

    text = fileW.read()
    if (not text):
        print("Nothing to read")
    else:
        print(text)
# Out:
# Position after open for append: 91
# Nothing to read
# Position after seek: 0
# Text line 1
# Text line 2
# Text line 3
# Text line 4
# Text line 5
# Text line 6
# Text line 7

# %% [markdown]
# ## Copy a file

# %%
# Read file and write to another file
with open("junk2.txt", "r") as fileR:
    with open("junk3.txt", "w") as fileW:
        for line in fileR:
            fileW.write(line)

# Read back to check
with open("junk3.txt", "r") as fileR:
    print(fileR.read())
# Out:
# Text line 1
# Text line 2
# Text line 3
# Text line 4
# Text line 5
# Text line 6
# Text line 7
