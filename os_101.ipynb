# %% [markdown]
# # OS 101

# %%
import os
print(os.name)
# Out:
# posix

# %%
# Get current working directory
print(os.getcwd())
# Out:
# /home/jari/MyGithub/Python_Snippets

# %%
# Add a file name
file_path = os.path.join(os.getcwd(), 'foo.txt')
print(file_path)
# Out:
# /home/jari/MyGithub/Python_Snippets/foo.txt

# %%
# Get base directory and file name
print("Dir name: ", os.path.dirname(file_path))
print("File name: ", os.path.basename(file_path))
print("File name split: ", os.path.splitext(os.path.basename(file_path)))
# Out:
# Dir name:  /home/jari/MyGithub/Python_Snippets
# File name:  foo.txt
# File name split:  ('foo', '.txt')

# %%
# Check if path exists
path = "c:\windows"
print(os.path.exists(path))
# Out:
# False

# %%
# Check if directory or file
path = "c:\windows"
print("Is directory? ", os.path.isdir(path))
print("Is file? ", os.path.isfile(path))
# Out:
# Is directory?  False
# Is file?  False
